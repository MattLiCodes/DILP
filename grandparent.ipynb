# %%
import tensorflow as tf
tf.compat.v1.enable_eager_execution()

from src.core import Term, Atom
from src.ilp import Language_Frame, Program_Template, Rule_Template
from src.dilp import DILP

# %%
atoms = [
    Atom([Term(False, 'alice'), Term(False, 'bob')], 'parent'),
    Atom([Term(False, 'bob'), Term(False, 'carl')], 'parent'),
    Atom([Term(False, 'david'), Term(False, 'emily')], 'parent'),
    Atom([Term(False, 'emily'), Term(False, 'frank')], 'parent'),
    Atom([Term(False, 'gary'), Term(False, 'helen')], 'parent'),
    Atom([Term(False, 'helen'), Term(False, 'ian')], 'parent')
]

predicates = {
    Atom([Term(True, 'X_0'), Term(True, 'X_1')], 'parent'),
    Atom([Term(True, 'X_0'), Term(True, 'X_1')], 'grandparent')
}

constants = {'alice', 'bob', 'carl', 'david', 'emily', 'frank', 'gary', 'helen', 'ian'}

# %%
positive_examples = [
    Atom([Term(False, 'alice'), Term(False, 'carl')], 'grandparent'),
    Atom([Term(False, 'david'), Term(False, 'frank')], 'grandparent'),
    Atom([Term(False, 'gary'), Term(False, 'ian')], 'grandparent')
]

negative_examples = [
    Atom([Term(False, 'alice'), Term(False, 'emily')], 'grandparent'),
    Atom([Term(False, 'bob'), Term(False, 'frank')], 'grandparent'),
    Atom([Term(False, 'gary'), Term(False, 'frank')], 'grandparent')
]

# %%
term_x_0 = Term(True, 'X_0')
term_x_1 = Term(True, 'X_1')
p_e = list(predicates)
p_a = [Atom([term_x_0, term_x_1], 'grandparent')]
target = Atom([term_x_0, term_x_1], 'grandparent')

p_a_rule = (Rule_Template(1, False), None)
target_rule = (Rule_Template(0, False), Rule_Template(1, True))
rules = {p_a[0]: p_a_rule, target: target_rule}

# %%
language_frame = Language_Frame(target, p_e, constants)
program_template = Program_Template(p_a, rules, 10)

dilp = DILP(language_frame, atoms, positive_examples, negative_examples, program_template)
dilp.train(steps=250)
# Out:
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 0 loss is 0.4984273910522461
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# grandparent(david,frank) Expected: 1 0.434
# grandparent(bob,frank) Expected: 0 0.175
# grandparent(gary,frank) Expected: 0 0.106
# grandparent(gary,ian) Expected: 1 0.434
# grandparent(alice,carl) Expected: 1 0.434
# grandparent(alice,emily) Expected: 0 0.168
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 1 loss is 0.4982263743877411
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 2 loss is 0.49801430106163025
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 3 loss is 0.4977909028530121
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 4 loss is 0.4975554049015045
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 5 loss is 0.49730709195137024
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# grandparent(david,frank) Expected: 1 0.435
# grandparent(bob,frank) Expected: 0 0.176
# grandparent(gary,frank) Expected: 0 0.106
# grandparent(gary,ian) Expected: 1 0.435
# grandparent(alice,carl) Expected: 1 0.435
# grandparent(alice,emily) Expected: 0 0.168
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 6 loss is 0.4970454275608063
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 7 loss is 0.4967697560787201
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 8 loss is 0.4964791238307953
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 9 loss is 0.4961727559566498
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 10 loss is 0.49584993720054626
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# grandparent(david,frank) Expected: 1 0.437
# grandparent(bob,frank) Expected: 0 0.176
# grandparent(gary,frank) Expected: 0 0.107
# grandparent(gary,ian) Expected: 1 0.437
# grandparent(alice,carl) Expected: 1 0.437
# grandparent(alice,emily) Expected: 0 0.169
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 11 loss is 0.49550941586494446
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 12 loss is 0.49515071511268616
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 13 loss is 0.49477264285087585
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 14 loss is 0.4943740665912628
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 15 loss is 0.493953675031662
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# grandparent(david,frank) Expected: 1 0.439
# grandparent(bob,frank) Expected: 0 0.177
# grandparent(gary,frank) Expected: 0 0.107
# grandparent(gary,ian) Expected: 1 0.439
# grandparent(alice,carl) Expected: 1 0.439
# grandparent(alice,emily) Expected: 0 0.170
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 246 loss is 0.0004958444624207914
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 247 loss is 0.0004746930208057165
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 248 loss is 0.0004545062256511301
# --------------------
#
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# Performing Inference
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Inference Complete
# --------------------
# step 249 loss is 0.0004352640826255083
# --------------------
# [0.4984273910522461,
#  0.4982263743877411,
#  0.49801430106163025,
#  0.4977909028530121,
#  0.4975554049015045,
#  0.49730709195137024,
#  0.4970454275608063,
#  0.4967697560787201,
#  0.4964791238307953,
#  0.4961727559566498,
#  0.49584993720054626,
#  0.49550941586494446,
#  0.49515071511268616,
#  0.49477264285087585,
#  0.4943740665912628,
#  0.493953675031662,
#  0.4935109317302704,
#  0.49304404854774475,
#  0.4925521910190582,
#  0.49203386902809143,
#  0.491487592458725,
#  0.4909120500087738,
#  0.49030551314353943,
#  0.489666223526001,
#  0.48899292945861816,
#  0.48828330636024475,
#  0.48753583431243896,
#  0.48674842715263367,
#  0.48591867089271545,
#  0.4850446879863739,
#  0.48412418365478516,
#  0.48315438628196716,
#  0.482133150100708,
#  0.4810578525066376,
#  0.47992560267448425,
#  0.47873377799987793,
#  0.47747930884361267,
#  0.4761589765548706,
#  0.47476983070373535,
#  0.4733083248138428,
#  0.471771240234375,
#  0.47015511989593506,
#  0.46845635771751404,
#  0.466671347618103,
#  0.464796781539917,
#  0.4628286361694336,
#  0.4607638418674469,
#  0.4585987627506256,
#  0.45633187890052795,
#  0.45395979285240173,
#  0.45147833228111267,
#  0.4488861858844757,
#  0.4461804926395416,
#  0.44335994124412537,
#  0.4404238760471344,
#  0.4373725950717926,
#  0.43420615792274475,
#  0.43092653155326843,
#  0.42753657698631287,
#  0.4240396022796631,
#  0.42044106125831604,
#  0.41675350069999695,
#  0.4129774570465088,
#  0.40912023186683655,
#  0.4051917791366577,
#  0.40120232105255127,
#  0.39716243743896484,
#  0.3930860459804535,
#  0.38898730278015137,
#  0.38487160205841064,
#  0.38075125217437744,
#  0.3766368329524994,
#  0.372537225484848,
#  0.36846137046813965,
#  0.36441612243652344,
#  0.3604104518890381,
#  0.3564527928829193,
#  0.35253724455833435,
#  0.34866294264793396,
#  0.34482812881469727,
#  0.3410283029079437,
#  0.33725693821907043,
#  0.33350539207458496,
#  0.32976290583610535,
#  0.326021283864975,
#  0.322277694940567,
#  0.3185053765773773,
#  0.31468889117240906,
#  0.31081220507621765,
#  0.3068593740463257,
#  0.3028141260147095,
#  0.2986607253551483,
#  0.294394314289093,
#  0.2900068461894989,
#  0.2854750156402588,
#  0.28078824281692505,
#  0.27593857049942017,
#  0.27092936635017395,
#  0.2657640874385834,
#  0.2604314982891083,
#  0.2549375593662262,
#  0.24928414821624756,
#  0.24349606037139893,
#  0.2375708818435669,
#  0.23153440654277802,
#  0.2253856062889099,
#  0.21912366151809692,
#  0.21278376877307892,
#  0.20635712146759033,
#  0.1998707503080368,
#  0.1933467835187912,
#  0.18681617081165314,
#  0.1803159862756729,
#  0.17385061085224152,
#  0.16743643581867218,
#  0.1610880047082901,
#  0.15484267473220825,
#  0.14869946241378784,
#  0.1426718682050705,
#  0.13677893579006195,
#  0.1310480684041977,
#  0.1254761666059494,
#  0.12005969136953354,
#  0.11480536311864853,
#  0.10972211509943008,
#  0.10480781644582748,
#  0.10006707906723022,
#  0.09550729393959045,
#  0.09112855046987534,
#  0.08693090826272964,
#  0.08290479332208633,
#  0.07904789596796036,
#  0.0753580778837204,
#  0.07183588296175003,
#  0.06848286837339401,
#  0.06528700888156891,
#  0.062238842248916626,
#  0.0593351274728775,
#  0.05657203868031502,
#  0.053943753242492676,
#  0.051442503929138184,
#  0.04906298220157623,
#  0.04680013656616211,
#  0.044648751616477966,
#  0.04260389879345894,
#  0.04066060855984688,
#  0.038814302533864975,
#  0.0370599627494812,
#  0.03539293631911278,
#  0.0338088683784008,
#  0.032303586602211,
#  0.03087306022644043,
#  0.02951337955892086,
#  0.02822056971490383,
#  0.02699165605008602,
#  0.02582372911274433,
#  0.024712584912776947,
#  0.023655131459236145,
#  0.022648582234978676,
#  0.021690070629119873,
#  0.020776940509676933,
#  0.01990712247788906,
#  0.01907828263938427,
#  0.01828780770301819,
#  0.01753380335867405,
#  0.016814308241009712,
#  0.01612761802971363,
#  0.01547191757708788,
#  0.014845576137304306,
#  0.01424705982208252,
#  0.013675711117684841,
#  0.013130624778568745,
#  0.012610204517841339,
#  0.0121120261028409,
#  0.011635790579020977,
#  0.011179487220942974,
#  0.010742463171482086,
#  0.010323873721063137,
#  0.009922382421791553,
#  0.009537027217447758,
#  0.009167104959487915,
#  0.00881197303533554,
#  0.008470947854220867,
#  0.008143234997987747,
#  0.007828363217413425,
#  0.007525671273469925,
#  0.007234633434563875,
#  0.006954648066312075,
#  0.006685392931103706,
#  0.0064261979423463345,
#  0.006176723632961512,
#  0.005936452653259039,
#  0.00570514565333724,
#  0.005482187028974295,
#  0.005267340689897537,
#  0.005060208961367607,
#  0.004860438406467438,
#  0.004667803645133972,
#  0.004481920972466469,
#  0.004302555695176125,
#  0.004129345063120127,
#  0.003962086047977209,
#  0.0038005353417247534,
#  0.0036444803699851036,
#  0.003493598895147443,
#  0.0033478185068815947,
#  0.0032068577129393816,
#  0.003070634789764881,
#  0.0029388873372226954,
#  0.00281163421459496,
#  0.002688573906198144,
#  0.002569675212725997,
#  0.002454866422340274,
#  0.0023440958466380835,
#  0.0022372230887413025,
#  0.0021343063563108444,
#  0.0020352446008473635,
#  0.0019400065066292882,
#  0.0018485510954633355,
#  0.0017609071219339967,
#  0.0016770135844126344,
#  0.001596790156327188,
#  0.0015202356735244393,
#  0.0014472593320533633,
#  0.001377781038172543,
#  0.001311670639552176,
#  0.0012488578213378787,
#  0.0011892522452399135,
#  0.0011328133987262845,
#  0.0010791529202833772,
#  0.0010283897863700986,
#  0.000980354379862547,
#  0.0009347976301796734,
#  0.0008916098740883172,
#  0.0008507805760018528,
#  0.0008120412821881473,
#  0.0007753120735287666,
#  0.0007405528449453413,
#  0.0007075348985381424,
#  0.0006761584081687033,
#  0.0006463836180046201,
#  0.0006181108765304089,
#  0.0005911810440011322,
#  0.0005656238063238561,
#  0.0005412500468082726,
#  0.0005180102307349443,
#  0.0004958444624207914,
#  0.0004746930208057165,
#  0.0004545062256511301,
#  0.0004352640826255083]

# %%
dilp.show_definition()
# Out:
# ----------------------------
# grandparent(X_0,X_1)
# grandparent(X_0,X_1) -> parent(X_0,X_2),parent(X_2,X_1)
# ----------------------------
